# %% [markdown]
# # Name - Aryan Jain
# # Task 6 - Prediction using Decision Tree Algorithm
# # GRIP - The Sparks Foundation

# %%
# Importing Libraries

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
from IPython.display import Image

from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load Data

# %%
iris = load_iris()
X=iris.data[:,:] 
y=iris.target

# %%
data=pd.DataFrame(iris['data'],columns=["Petal length","Petal Width","Sepal Length","Sepal Width"])
data['species']=iris['target']
data['species']=data['species'].apply(lambda x: iris['target_names'][x])

data.head()
# Out:
#    Petal length  Petal Width  Sepal Length  Sepal Width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.shape
# Out:
# (150, 5)

# %%
data.describe()
# Out:
#        Petal length  Petal Width  Sepal Length  Sepal Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Data Visualization

# %%
sns.pairplot(data=data,hue='species')

# %%
sns.FacetGrid(data,hue='species',height=4,aspect=1).map(plt.scatter,'Sepal Length','Sepal Width').add_legend()
plt.show()

# Scatter plot of data based on Petal Length and Width features
sns.FacetGrid(data,hue='species',height =4,aspect=1).map(plt.scatter,'Petal length','Petal Width').add_legend()
plt.show()

# %% [markdown]
# # Model Training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1) 
tree_classifier = DecisionTreeClassifier()
tree_classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
y_pred = tree_classifier.predict(X_test)

# %% [markdown]
# # Comapring Actual and Predicted Classification

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred}) 
df
# Out:
#     Actual  Predicted
# 0        2          2
# 1        1          1
# 2        0          0
# 3        2          2
# 4        1          1
# 5        2          2
# 6        0          0
# 7        2          2
# 8        1          1
# 9        0          0
# 10       1          1
# 11       0          0
# 12       1          1
# 13       2          2
# 14       1          1

# %% [markdown]
# # Visualizing trained model

# %%
df.plot(kind='bar',figsize=(10,8))

# %%
Image(filename='decision_tree.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-27ac5f912fd4> in <module>
# ----> 1 Image(filename='decision_tree.png')
#
# G:\anaconda 3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1195         self.unconfined = unconfined
#    1196         super(Image, self).__init__(data=data, url=url, filename=filename,
# -> 1197                 metadata=metadata)
#    1198
#    1199         if self.width is None and self.metadata.get('width', {}):
#
# G:\anaconda 3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, metadata)
#     618             self.metadata = {}
#     619
# --> 620         self.reload()
#     621         self._check_data()
#     622
#
# G:\anaconda 3\lib\site-packages\IPython\core\display.py in reload(self)
# ...

# %%
sample = [[1,2,2,3]]

# %%
tree_classifier.predict(sample)
# Out:
# array([0])

# %% [markdown]
# This sample case belongs to 2 i.e. virginica class.

# %% [markdown]
# # Model Accuracy

# %%
import sklearn.metrics as sm

# %%
print("Accuracy:",sm.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %% [markdown]
# # I was able carry out prediction and evaluated model's accuracy score

# %% [markdown]
# # The END
